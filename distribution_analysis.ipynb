# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

def loading_csv():

    df_malnutrition = pd.read_csv('df_malnutrition_nonNull.csv', encoding='utf-8')
    df_obesity = pd.read_csv('df_obesity_nonNull.csv', encoding='utf-8')
    return df_obesity,df_malnutrition

def univariant_analysis(df_malnutrition, df_obesity):
    #univariant on df_malnutrition
    
    plt.hist(df_malnutrition['Mean_Estimate'])
    plt.title("Distribution of Mean_Estimate in df_malnutrition with Histogram")
    plt.xlabel("Mean_Estimate")
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show() #Distribution of Mean_Estimate in df_malnutrition with Histogram

    sns.boxplot(x=df_malnutrition['Mean_Estimate'])
    plt.title("Distribution of Mean_Estimate in df_malnutrition with boxplot")
    plt.tight_layout()
    plt.show() #Distribution of Mean_Estimate in df_malnutrition with boxplot

    skew = df_malnutrition['Mean_Estimate'].skew()
    print("skew Estimate of df_malnutrition['Mean_Estimate']",skew)

    sns.histplot(df_malnutrition['Mean_Estimate'], kde=True, color='skyblue', bins=30)
    plt.title('Distribution of Mean_Estimate in df_malnutrition with Skewness')
    plt.xlabel('Mean_Estimate')
    plt.ylabel('Frequency')
    plt.show()#Distribution of Mean_Estimate in df_malnutrition with Skewness

    kurt_df_malnutrition = df_malnutrition['Mean_Estimate'].kurt()
    print(f"Kurtosis Estimate of df_malnutrition['Mean_Estimate']: {kurt_df_malnutrition}")
    
    #Detecting Outliers
    col = 'Mean_Estimate'
    data = df_malnutrition[col]

    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)]

    print(f'Outliers in {col}: {len(outliers)}')
    print(outliers.head())

    #univariant on df_malnutrition_nonNull

    plt.hist(df_obesity['Mean_Estimate'])
    plt.title("Distribution of Mean_Estimate in df_obesity with Histogram")
    plt.xlabel("Mean_Estimate")
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show() #Distribution of Mean_Estimate in df_obesity with Histogram

    sns.boxplot(x=df_obesity['Mean_Estimate'])
    plt.title("Distribution of Mean_Estimate in df_obesity with boxplot")
    plt.tight_layout()
    plt.show() #Distribution of Mean_Estimate in df_obesity with boxplot

    skew = df_obesity['Mean_Estimate'].skew()
    print("skew Estimate of df_obesity['Mean_Estimate']",skew)

    sns.histplot(df_obesity['Mean_Estimate'], kde=True, color='skyblue', bins=30)
    plt.title('Distribution of Mean_Estimate in df_obesity with Skewness')
    plt.xlabel('Mean_Estimate')
    plt.ylabel('Frequency')
    plt.show() #Distribution of Mean_Estimate in df_obesity with Skewness

    kurt_df_obesity = df_obesity['Mean_Estimate'].kurt()
    print(f"Kurtosis Estimate of df_obesity['Mean_Estimate']: {kurt_df_malnutrition}")
     
     #Detecting Outliers
    data = df_obesity[col]

    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)]

    print(f'Outliers in {col}: {len(outliers)}')
    print(outliers.head())

def distribution_of_CI_Width(df_malnutrition, df_obesity):
      #univariant on df_malnutrition
    
    plt.hist(df_malnutrition['CI_Width'])
    plt.title("Distribution of Mean_Estimate in df_malnutrition with Histogram")
    plt.xlabel("CI_Width")
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show() #Distribution of CI_Width in df_malnutrition with Histogram

    sns.boxplot(x=df_malnutrition['CI_Width'])
    plt.title("Distribution of CI_Width in df_malnutrition with boxplot")
    plt.tight_layout()
    plt.show() #Distribution of Mean_Estimate in df_malnutrition with boxplot

    skew = df_malnutrition['CI_Width'].skew()
    print("skew Estimate of df_malnutrition['CI_Width']",skew)

    sns.histplot(df_malnutrition['CI_Width'], kde=True, color='skyblue', bins=30)
    plt.title('Distribution of CI_Width in df_malnutrition with Skewness')
    plt.xlabel('Mean_CI_WidthEstimate')
    plt.ylabel('Frequency')
    plt.show()#Distribution of CI_Width in df_malnutrition with Skewness

    kurt_df_malnutrition = df_malnutrition['CI_Width'].kurt()
    print(f"Kurtosis Estimate of df_malnutrition['CI_Width']: {kurt_df_malnutrition}")
    
    #Detecting Outliers
    col = 'CI_Width'
    data = df_malnutrition[col]

    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)]

    print(f'Outliers in {col}: {len(outliers)}')
    print(outliers.head())

    #univariant on df_malnutrition_nonNull

    plt.hist(df_obesity['CI_Width'])
    plt.title("Distribution of CI_Width in df_obesity with Histogram")
    plt.xlabel("CI_Width")
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show() #Distribution of CI_Width in df_obesity with Histogram

    sns.boxplot(x=df_obesity['CI_Width'])
    plt.title("Distribution of CI_Width in df_obesity with boxplot")
    plt.tight_layout()
    plt.show() #Distribution of CI_Width in df_obesity with boxplot

    skew = df_obesity['CI_Width'].skew()
    print("skew Estimate of df_obesity['CI_Width']",skew)

    sns.histplot(df_obesity['CI_Width'], kde=True, color='skyblue', bins=30)
    plt.title('Distribution of CI_Width in df_obesity with Skewness')
    plt.xlabel('CI_Width')
    plt.ylabel('Frequency')
    plt.show() #Distribution of CI_Width in df_obesity with Skewness

    kurt_df_obesity = df_obesity['CI_Width'].kurt()
    print(f"Kurtosis Estimate of df_obesity['CI_Width']: {kurt_df_malnutrition}")
     
     #Detecting Outliers
    data = df_obesity[col]

    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = data[(data < lower_bound) | (data > upper_bound)]

    print(f'Outliers in {col}: {len(outliers)}')
    print(outliers.head())

    
def categorial_data_analysis(df_obesity,df_malnutrition):
       
    #df_obesity

    print(f"Classification Data of df_obesity['Obesity_level']: {df_obesity['Obesity_level'].value_counts()}")

    print(sns.countplot(x=df_obesity['Obesity_level']))
    plt.title("Distribution Of Obesity_level_Objects with countplot")
    plt.tight_layout()
    plt.show() #Distribution Of Obesity_level_Objects with countplot

    print(df_obesity['Obesity_level'].value_counts().plot.pie())
    plt.title("Distribution Of Obesity_level_Objects with pieplot")
    plt.tight_layout()
    plt.show() #Distribution Of Obesity_level_Objects with pieplot

    #df_malnutrition

    print(f"Classification Data of df_malnutrition['malnutrition_level']: {df_malnutrition['malnutrition_level'].value_counts()}")

    print(sns.countplot(x=df_malnutrition['malnutrition_level']))
    plt.title("Distribution Of malnutrition_level with countplot")
    plt.tight_layout()
    plt.show() #Distribution Of malnutrition_level objects with countplot

    print(df_malnutrition['malnutrition_level'].value_counts().plot.pie())
    plt.title("Distribution Of Obesity_level_Objects with pieplot")
    plt.tight_layout()
    plt.show()#Distribution Of malnutrition_level objects with pieplot

def bivariant_analysis(df_obesity,df_malnutrition):
    #Group and plot malnutrition
    #malnutrition
    ci_means_malnutrition = df_malnutrition.groupby('malnutrition_level')['CI_Width'].mean()
    print(ci_means_malnutrition)
    ci_means_malnutrition.plot.bar(
        color=['red', 'green', 'orange'],
        title='Average CI Width by Malnutrition Level'
    )
    plt.ylabel('CI_Width')
    plt.title("Grouping malnutrition_level with CI_Width malnutrition with barchart")
    plt.tight_layout()
    plt.show()#Grouping malnutrition_level with CI_Width malnutrition with barchart
     
    # Group by year and calculate average
    trend_df = df_malnutrition.groupby('Year')['Mean_Estimate'].mean().reset_index()

    # Plot
    sns.lineplot(data=trend_df, x='Year', y='Mean_Estimate', marker='o', color='teal')
    plt.title('Global Mean Estimate of Malnutrition Trend Over Time')
    plt.xlabel('Year')
    plt.ylabel('Mean Estimate (%)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()#Global Mean Estimate Trend Over Time


    
    #obesity
    # Group and plot obesity
    ci_means_obesity = df_obesity.groupby('Obesity_level')['CI_Width'].mean()
    print(ci_means_obesity)
    ci_means_obesity.plot.bar(
        color=['red', 'green', 'orange'],
        title='Average CI Width by Obesity Level'
    )
    plt.ylabel('CI_Width')
    plt.title("Grouping Obesity_level with CI_Width Obesity with barchart")
    plt.tight_layout()
    plt.show() #Grouping Obesity_level with CI_Width Obesity with barchart

    # Group by year and calculate average
    trend_df = df_obesity.groupby('Year')['Mean_Estimate'].mean().reset_index()

    # Plot
    sns.lineplot(data=trend_df, x='Year', y='Mean_Estimate', marker='o', color='teal')
    plt.title('Global Mean Estimate of Obesity Trend Over Time')
    plt.xlabel('Year')
    plt.ylabel('Mean Estimate (%)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()#Global Mean Estimate Trend Over Time

def mutivariant_analysis(df_obesity,df_malnutrition):
    #obesity

    grouped_df_obesity = df_obesity.groupby(['Region', 'age_group', 'Gender'])['Mean_Estimate'].mean().reset_index()

    #  Bar Plot – Region vs Gender
    plt.figure(figsize=(12, 6))
    sns.barplot(data=grouped_df_obesity, x='Region', y='Mean_Estimate', hue='Gender', ci=None)
    plt.title('Obesity by Region and Gender')
    plt.xlabel('Region')
    plt.ylabel('Mean Estimate (%)')
    plt.xticks(rotation=45)
    plt.legend(title='Gender')
    plt.tight_layout()
    plt.show()

    #  Line Plot – Trend Over Time by Region & Gender
    trend_df_obesity = df_obesity.groupby(['Year', 'Region', 'Gender'])['Mean_Estimate'].mean().reset_index()

    plt.figure(figsize=(14, 6))
    sns.lineplot(data=trend_df_obesity, x='Year', y='Mean_Estimate', hue='Gender', style='Region', markers=True)
    plt.title('Obesity Trend by Region and Gender Over Time')
    plt.xlabel('Year')
    plt.ylabel('Mean Estimate (%)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    #  Bar Plot – Region vs Age Group
    age_df_obesity = df_obesity.groupby(['Region', 'age_group'])['Mean_Estimate'].mean().reset_index()

    plt.figure(figsize=(10, 6))
    sns.barplot(data=age_df_obesity, x='Region', y='Mean_Estimate', hue='age_group', ci=None)
    plt.title('Obesity by Region and Age Group')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    #  Faceted Plot – Region × Age Group × Gender
    combo_df_obesity = df_obesity.groupby(['Region', 'age_group', 'Gender'])['Mean_Estimate'].mean().reset_index()

    g = sns.FacetGrid(combo_df_obesity, col='age_group', row='Gender', height=4, aspect=1.5)
    g.map_dataframe(sns.barplot, x='Region', y='Mean_Estimate', order=combo_df_obesity['Region'].unique())
    g.set_titles(row_template='{row_name}', col_template='{col_name}')
    g.set_xticklabels(rotation=45)
    g.fig.subplots_adjust(top=0.9)
    g.fig.suptitle('Obeity by Region, Age Group, and Gender')
    plt.show()

    #MALNUTRITION

    grouped_df_malnutrition = df_malnutrition.groupby(['Region', 'age_group', 'Gender'])['Mean_Estimate'].mean().reset_index()

    #  Bar Plot – Region vs Gender
    plt.figure(figsize=(12, 6))
    sns.barplot(data=grouped_df_malnutrition, x='Region', y='Mean_Estimate', hue='Gender', ci=None)
    plt.title('Malnutrition by Region and Gender')
    plt.xlabel('Region')
    plt.ylabel('Mean Estimate (%)')
    plt.xticks(rotation=45)
    plt.legend(title='Gender')
    plt.tight_layout()
    plt.show()

    #  Line Plot – Trend Over Time by Region & Gender
    trend_df_malnutrition= df_malnutrition.groupby(['Year', 'Region', 'Gender'])['Mean_Estimate'].mean().reset_index()

    plt.figure(figsize=(14, 6))
    sns.lineplot(data=trend_df_malnutrition, x='Year', y='Mean_Estimate', hue='Gender', style='Region', markers=True)
    plt.title(' Malnutrition Trend by Region and Gender Over Time')
    plt.xlabel('Year')
    plt.ylabel('Mean Estimate (%)')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

    #  Bar Plot – Region vs Age Group
    age_df_malnutrition =  df_malnutrition.groupby(['Region', 'age_group'])['Mean_Estimate'].mean().reset_index()

    plt.figure(figsize=(10, 6))
    sns.barplot(data=age_df_malnutrition, x='Region', y='Mean_Estimate', hue='age_group', ci=None)
    g.fig.suptitle('Malnutrition by Region, Age Group, and Gender')
    plt.title('Malnutrition by Region and Age Group')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    #  Faceted Plot – Region × Age Group × Gender
    combo_df_malnutrition = df_malnutrition.groupby(['Region', 'age_group', 'Gender'])['Mean_Estimate'].mean().reset_index()

    g = sns.FacetGrid(combo_df_malnutrition, col='age_group', row='Gender', height=4, aspect=1.5)
    g.map_dataframe(sns.barplot, x='Region', y='Mean_Estimate', order=combo_df_malnutrition['Region'].unique())
    g.set_titles(row_template='{row_name}', col_template='{col_name}')
    g.set_xticklabels(rotation=45)
    g.fig.subplots_adjust(top=0.9)
    g.fig.suptitle('Malnutrition by Region, Age Group, and Gender')
    plt.show()


    
def main():
        df_obesity,df_malnutrition = loading_csv()
        univariant_analysis(df_malnutrition, df_obesity)
        distribution_of_CI_Width(df_malnutrition, df_obesity)
        categorial_data_analysis(df_obesity,df_malnutrition)
        bivariant_analysis(df_obesity,df_malnutrition)
        mutivariant_analysis(df_obesity,df_malnutrition)
main()
# Out:
# skew Estimate of df_malnutrition['Mean_Estimate'] 1.8966918627306584
# Kurtosis Estimate of df_malnutrition['Mean_Estimate']: 4.453943689084184
# Outliers in Mean_Estimate: 1499
# 56     15.302272
# 68     15.372814
# 92     15.038051
# 127    33.514586
# 132    16.493754
# Name: Mean_Estimate, dtype: float64
# skew Estimate of df_obesity['Mean_Estimate'] 1.8301342445345938
# Kurtosis Estimate of df_obesity['Mean_Estimate']: 4.453943689084184
# Outliers in Mean_Estimate: 877
# 6     41.919816
# 20    80.316889
# 28    66.781110
# 36    48.850262
# 47    55.414408
# Name: Mean_Estimate, dtype: float64
# skew Estimate of df_malnutrition['CI_Width'] 1.4653728714984704
# Kurtosis Estimate of df_malnutrition['CI_Width']: 1.9680604480215904
# Outliers in CI_Width: 1178
# 76     18.169074
# 92     15.770422
# 103    20.130325
# 132    15.106917
# 186    18.158182
# Name: CI_Width, dtype: float64
# skew Estimate of df_obesity['CI_Width'] 1.521211046294168
# ...
